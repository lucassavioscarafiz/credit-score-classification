# %% [markdown]
# # 4. Inference Pipeline

# %% [markdown]
# This notebook execute the preprocessing.py and the inference.py archives.
#
# 1) `preprocessing.py`:
#
# -function `get_data()`: load the 'test.csv' file;
#
# -function `feats_transform_type()`: treat the datatypes of the inference dataset;
#
# -function `preprocessing_data()`: make the feature engineering process in the inference dataset.
#
# 2) `inference.py`:
#
# -function `model_fn()`: load the best model created in the notebook: 3_modelling.ipynb
#
# -function `load_data()`: load the 'inference_data.csv' file;
#
# -function `predict_fn()`: create the predictions (score) and the bins (gh) groups of the model.

# %%
import pandas as pd
import sys
import os
import subprocess
# Out:
# C:\Users\lucas\AppData\Roaming\Python\Python310\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
# Executing the pre processing script
print("Running pre processing...")
subprocess.run(["python", "../src/inference_pipe/preprocessing.py"], check=True)

# Executing the inference script
print("Running the inference...")
subprocess.run(["python", "../src/inference_pipe/inference.py"], check=True)

# loading the results...
df_result = pd.read_csv("../data/inference_data_scored.csv")
print("Examples:")
display(df_result.head())
# Out:
# Running pre processing...
# Running the inference...
# Examples:
#    Unnamed: 0.1  Unnamed: 0      id customer_id      month             name  \
# 0             0           0  0x160a   CUS_0xd40  September    Aaron Maashoh
# 1             1           1  0x160b   CUS_0xd40    October    Aaron Maashoh
# 2             2           2  0x160c   CUS_0xd40   November    Aaron Maashoh
# 3             3           3  0x160d   CUS_0xd40   December    Aaron Maashoh
# 4             4           4  0x1616  CUS_0x21b1  September  Rick Rothackerj
#
#    age          ssn  occupation  annual_income  ...  credit_utilization_ratio  \
# 0   23  821-00-0265    0.632461       19114.12  ...                 35.030402
# 1   24  821-00-0265    0.632461       19114.12  ...                 33.053114
# 2   24  821-00-0265    0.632461       19114.12  ...                 33.811894
# 3   24  821-00-0265    0.632461       19114.12  ...                 32.430559
# ...
